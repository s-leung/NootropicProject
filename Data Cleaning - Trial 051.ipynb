# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Trial_051_deident.csv', parse_dates=['Start Date', 'End Date'])
df.head()
# Out:
#            Start Date            End Date First Name  \
# 0 2017-11-15 12:23:00 2017-11-15 12:25:00      User1
# 1 2017-11-09 13:13:00 2017-11-09 13:16:00      User1
# 2 2017-10-31 10:18:00 2017-10-31 10:23:00      User1
# 3 2017-10-27 12:49:00 2017-10-27 12:52:00      User1
# 4 2017-11-16 19:45:00 2017-11-16 19:48:00      User2
#
#   For how long have you tried this version? Sleep_Quality  \
# 0                                   3 weeks            OK
# 1                                   2 weeks            OK
# 2                           1 week (5 days)            OK
# 3                                     1 day          Poor
# 4                                   3 weeks            OK
#
#   Overall, your experience with this product so far is  \
# 0                                               Good
# 1                                               Good
# 2                                               Good
# 3                                               Good
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 19 columns):
# Start Date                                                                    133 non-null datetime64[ns]
# End Date                                                                      133 non-null datetime64[ns]
# First Name                                                                    133 non-null object
# For how long have you tried this version?                                     133 non-null object
# Sleep_Quality                                                                 132 non-null object
# Overall, your experience with this product so far is                          133 non-null object
# Focus/ Attention/ Concentration -                                             132 non-null object
# Memory (short and long term) -                                                132 non-null object
# ...

# %%
df = df.rename(columns={'Start Date': 'Start_Date',
                  'End Date': 'End_Date',
                  'First Name': 'Last_Name',
                  'For how long have you tried this version?' : 'Version_Duration',
                  'Sleep_Quality' : 'Sleep_Quality',
                  'Overall, your experience with this product so far is': 'Overall_Experience',
                  'Focus/ Attention/ Concentration - ': 'Focus_Atten_Concen',
                  'Memory (short and long term) - ': 'Memory',
                  'Drive/ Passion/ Motivation - ': 'Drive_Passion_Motivation',
                  'Physical Energy - ': 'Physical_Energy',
                  'Capacity/ productivity - ': 'Capacity_Productivity',
                  'Decisiveness - ': 'Decisiveness',
                  'Verbal fluency / word recall - ': 'Verbal_Fluency_Word_Recall',
                  'Creativity / insight - ': 'Creativity_Insight',
                  'Interpersonal capability / empathy - ': 'InterpersonalCapability_Empathy',
                  'Emotional stability - ': 'Emotional_Stability',
                  'Euphoria / joy / happiness - ': 'Euhphoria_Joy_Happiness',
                  'Estimated_Effect_Aprox' : 'Estimated_Effect_Duration',
                  'If you are a current user of the Drug, how would you compare this formula?': 'Current_User_Comparison'})

# %%
df.head()
# Out:
#            Start_Date            End_Date Last_Name Version_Duration  \
# 0 2017-11-15 12:23:00 2017-11-15 12:25:00     User1          3 weeks
# 1 2017-11-09 13:13:00 2017-11-09 13:16:00     User1          2 weeks
# 2 2017-10-31 10:18:00 2017-10-31 10:23:00     User1  1 week (5 days)
# 3 2017-10-27 12:49:00 2017-10-27 12:52:00     User1            1 day
# 4 2017-11-16 19:45:00 2017-11-16 19:48:00     User2          3 weeks
#
#   Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 0            OK               Good           Improved   Improved
# 1            OK               Good           Improved   Improved
# 2            OK               Good           Improved   Improved
# 3          Poor               Good           Improved  No effect
# 4            OK          No effect          No effect  No effect
#
#   Drive_Passion_Motivation Physical_Energy Capacity_Productivity Decisiveness  \
# ...

# %%
df.describe()
# Out:
#                  Start_Date             End_Date Last_Name Version_Duration  \
# count                   133                  133       133              133
# unique                  131                  132        47                4
# top     2017-11-17 08:31:00  2017-11-06 12:40:00    User12            1 day
# freq                      2                    2         4               42
# first   2017-10-26 21:03:00  2017-10-26 21:06:00       NaN              NaN
# last    2017-11-25 06:05:00  2017-11-25 06:08:00       NaN              NaN
#
#        Sleep_Quality Overall_Experience Focus_Atten_Concen    Memory  \
# count            132                133                132       132
# unique             3                  5                  3         3
# top               OK               Good           Improved  Improved
# freq              72                 69                112        74
# first            NaN                NaN                NaN       NaN
# ...

# %%
df.Estimated_Effect_Duration.value_counts()
# Out:
# 4 to 8 hours         62
# More than 8 hours    31
# 2 to 4 hours         16
# Less than 2 hours    15
# Name: Estimated_Effect_Duration, dtype: int64

# %%
df['Estimated_Effect_Duration'] = df['Estimated_Effect_Duration'].map({'4 to 8 hours': '4-8',
    'More than 8 hours': '8+',
    '2 to 4 hours': '2-4',
    'Less than 2 hours': '<2'})

# %%
#converting hour range into numeric numbers with upper and lower bounds of the bins 
upper  = {'4-8': 8,
         '2-4': 4,
         '8+': 12,
         '<2': 2}
df['Upper_Effect_Duration'] = df['Estimated_Effect_Duration'].map(upper)


lower = {'4-8': 4,
        '2-4':2, 
        '8+': 8,
        '<2': 0}
df['Lower_Effect_Duration'] = df['Estimated_Effect_Duration'].map(lower)

# %%
df.head()
# Out:
#            Start_Date            End_Date Last_Name Version_Duration  \
# 0 2017-11-15 12:23:00 2017-11-15 12:25:00     User1          3 weeks
# 1 2017-11-09 13:13:00 2017-11-09 13:16:00     User1          2 weeks
# 2 2017-10-31 10:18:00 2017-10-31 10:23:00     User1  1 week (5 days)
# 3 2017-10-27 12:49:00 2017-10-27 12:52:00     User1            1 day
# 4 2017-11-16 19:45:00 2017-11-16 19:48:00     User2          3 weeks
#
#   Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 0            OK               Good           Improved   Improved
# 1            OK               Good           Improved   Improved
# 2            OK               Good           Improved   Improved
# 3          Poor               Good           Improved  No effect
# 4            OK          No effect          No effect  No effect
#
#   Drive_Passion_Motivation Physical_Energy          ...            \
# 0                 Improved        Improved          ...
# ...

# %%
df.Version_Duration.value_counts()
# Out:
# 1 day              42
# 1 week (5 days)    40
# 2 weeks            31
# 3 weeks            20
# Name: Version_Duration, dtype: int64

# %%
week = '1 week ' + '(' + '5 days' + ')'

df['Version_Duration'] = df['Version_Duration'].map({ week : '1 weeks', '1 day': '1 day', '2 weeks':'2 weeks', '3 weeks': '3 weeks'})

# %%
df.head()
# Out:
#            Start_Date            End_Date Last_Name Version_Duration  \
# 0 2017-11-15 12:23:00 2017-11-15 12:25:00     User1          3 weeks
# 1 2017-11-09 13:13:00 2017-11-09 13:16:00     User1          2 weeks
# 2 2017-10-31 10:18:00 2017-10-31 10:23:00     User1          1 weeks
# 3 2017-10-27 12:49:00 2017-10-27 12:52:00     User1            1 day
# 4 2017-11-16 19:45:00 2017-11-16 19:48:00     User2          3 weeks
#
#   Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 0            OK               Good           Improved   Improved
# 1            OK               Good           Improved   Improved
# 2            OK               Good           Improved   Improved
# 3          Poor               Good           Improved  No effect
# 4            OK          No effect          No effect  No effect
#
#   Drive_Passion_Motivation Physical_Energy          ...            \
# 0                 Improved        Improved          ...
# ...

# %%
df.Current_User_Comparison.value_counts()
# Out:
# This is better than XNootropic          42
# I am not a XNootropic user              30
# This is about the same as XNootropic    30
# This is less good than XNootropic       24
# Name: Current_User_Comparison, dtype: int64

# %%
user = {'I am not a XNootropic user': 'Non-user',
        'This is less good than XNootropic':'XNootropic User',
        'This is better than XNootropic': 'XNootropic User',
        'This is about the same as XNootropic' : 'XNootropic User'}


df['User_Status'] = df['Current_User_Comparison'].map(user)

# %%
df.head()
# Out:
#            Start_Date            End_Date Last_Name Version_Duration  \
# 0 2017-11-15 12:23:00 2017-11-15 12:25:00     User1          3 weeks
# 1 2017-11-09 13:13:00 2017-11-09 13:16:00     User1          2 weeks
# 2 2017-10-31 10:18:00 2017-10-31 10:23:00     User1          1 weeks
# 3 2017-10-27 12:49:00 2017-10-27 12:52:00     User1            1 day
# 4 2017-11-16 19:45:00 2017-11-16 19:48:00     User2          3 weeks
#
#   Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 0            OK               Good           Improved   Improved
# 1            OK               Good           Improved   Improved
# 2            OK               Good           Improved   Improved
# 3          Poor               Good           Improved  No effect
# 4            OK          No effect          No effect  No effect
#
#   Drive_Passion_Motivation Physical_Energy     ...       \
# 0                 Improved        Improved     ...
# ...

# %%
#rearranging the column order so that they match
cols = df.columns.tolist()
col = cols[0:18] + cols[19:21] + cols[18:19] + cols[21:]
df = df[col]

# %%
df.head()
# Out:
#            Start_Date            End_Date Last_Name Version_Duration  \
# 0 2017-11-15 12:23:00 2017-11-15 12:25:00     User1          3 weeks
# 1 2017-11-09 13:13:00 2017-11-09 13:16:00     User1          2 weeks
# 2 2017-10-31 10:18:00 2017-10-31 10:23:00     User1          1 weeks
# 3 2017-10-27 12:49:00 2017-10-27 12:52:00     User1            1 day
# 4 2017-11-16 19:45:00 2017-11-16 19:48:00     User2          3 weeks
#
#   Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 0            OK               Good           Improved   Improved
# 1            OK               Good           Improved   Improved
# 2            OK               Good           Improved   Improved
# 3          Poor               Good           Improved  No effect
# 4            OK          No effect          No effect  No effect
#
#   Drive_Passion_Motivation Physical_Energy     ...       \
# 0                 Improved        Improved     ...
# ...

# %%
(df.duplicated(subset=['Last_Name','Version_Duration'])).value_counts()
# Out:
# False    133
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 22 columns):
# Start_Date                         133 non-null datetime64[ns]
# End_Date                           133 non-null datetime64[ns]
# Last_Name                          133 non-null object
# Version_Duration                   133 non-null object
# Sleep_Quality                      132 non-null object
# Overall_Experience                 133 non-null object
# Focus_Atten_Concen                 132 non-null object
# Memory                             132 non-null object
# Drive_Passion_Motivation           132 non-null object
# Physical_Energy                    132 non-null object
# Capacity_Productivity              131 non-null object
# Decisiveness                       132 non-null object
# Verbal_Fluency_Word_Recall         129 non-null object
# Creativity_Insight                 130 non-null object
# InterpersonalCapability_Empathy    132 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# Start_Date                          0
# End_Date                            0
# Last_Name                           0
# Version_Duration                    0
# Sleep_Quality                       1
# Overall_Experience                  0
# Focus_Atten_Concen                  1
# Memory                              1
# Drive_Passion_Motivation            1
# Physical_Energy                     1
# Capacity_Productivity               2
# Decisiveness                        1
# Verbal_Fluency_Word_Recall          4
# Creativity_Insight                  3
# InterpersonalCapability_Empathy     1
# Emotional_Stability                 1
# Euhphoria_Joy_Happiness             1
# Estimated_Effect_Duration          25
# Upper_Effect_Duration              25
# Lower_Effect_Duration              25
# Current_User_Comparison             7
# User_Status                         7
# dtype: int64

# %% [markdown]
# ### Sleep Quality:
#
# User 20 did not respond about sleep quality and has only one row of data to which they answered on Day 1

# %%
df[df.Sleep_Quality.isnull()]
# Out:
#             Start_Date            End_Date Last_Name Version_Duration  \
# 55 2017-10-30 20:54:00 2017-10-30 21:00:00    User20            1 day
#
#    Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 55           NaN               Good           Improved  No effect
#
#    Drive_Passion_Motivation Physical_Energy       ...         \
# 55                 Improved        Improved       ...
#
#    Verbal_Fluency_Word_Recall Creativity_Insight  \
# 55                  No effect          No effect
#
#    InterpersonalCapability_Empathy Emotional_Stability  \
# 55                       Less good            Improved
#
#    Euhphoria_Joy_Happiness Estimated_Effect_Duration Upper_Effect_Duration  \
# 55               No effect                       4-8                   8.0
#
#    Lower_Effect_Duration         Current_User_Comparison      User_Status
# 55                   4.0  This is better than XNootropic  XNootropic User
#
# [1 rows x 22 columns]

# %%
df[df.Last_Name=='User20']
# Out:
#             Start_Date            End_Date Last_Name Version_Duration  \
# 55 2017-10-30 20:54:00 2017-10-30 21:00:00    User20            1 day
#
#    Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 55           NaN               Good           Improved  No effect
#
#    Drive_Passion_Motivation Physical_Energy       ...         \
# 55                 Improved        Improved       ...
#
#    Verbal_Fluency_Word_Recall Creativity_Insight  \
# 55                  No effect          No effect
#
#    InterpersonalCapability_Empathy Emotional_Stability  \
# 55                       Less good            Improved
#
#    Euhphoria_Joy_Happiness Estimated_Effect_Duration Upper_Effect_Duration  \
# 55               No effect                       4-8                   8.0
#
#    Lower_Effect_Duration         Current_User_Comparison      User_Status
# 55                   4.0  This is better than XNootropic  XNootropic User
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Focus and Attention
#
# User37 did not respond to Day 1's rsponses to Focus and Attention. This person only responded on Day 1 to sleep quality, overall experience, and no other questions after that.  However, this person did answer for Week 1 and Week 2. Can I impute their answers based on other answers.

# %%
df[df.Focus_Atten_Concen.isnull()].isnull().sum()
# Out:
# Start_Date                         0
# End_Date                           0
# Last_Name                          0
# Version_Duration                   0
# Sleep_Quality                      0
# Overall_Experience                 0
# Focus_Atten_Concen                 1
# Memory                             1
# Drive_Passion_Motivation           1
# Physical_Energy                    1
# Capacity_Productivity              1
# Decisiveness                       1
# Verbal_Fluency_Word_Recall         1
# Creativity_Insight                 1
# InterpersonalCapability_Empathy    1
# Emotional_Stability                1
# Euhphoria_Joy_Happiness            1
# Estimated_Effect_Duration          1
# Upper_Effect_Duration              1
# Lower_Effect_Duration              1
# Current_User_Comparison            1
# User_Status                        1
# dtype: int64

# %%
US37 = df[df.Last_Name=='User37']
US37
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 101 2017-11-20 09:04:00 2017-11-20 09:07:00    User37          2 weeks
# 102 2017-11-13 14:44:00 2017-11-13 14:47:00    User37          1 weeks
# 103 2017-11-07 07:56:00 2017-11-07 07:59:00    User37            1 day
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 101     Excellent               Good           Improved  No effect
# 102     Excellent               Good          No effect  No effect
# 103     Excellent               Good                NaN        NaN
#
#     Drive_Passion_Motivation Physical_Energy       ...         \
# 101                 Improved        Improved       ...
# 102                 Improved       No effect       ...
# 103                      NaN             NaN       ...
#
#     Verbal_Fluency_Word_Recall Creativity_Insight  \
# 101                  No effect           Improved
# 102                  Less good          No effect
# ...

# %%
(US37.loc[101:101,'User_Status']).fillna('XNootropic User', inplace=True)
#filling in User Status since it's known, but cannot put in current user comparison

# %%
US37
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 101 2017-11-20 09:04:00 2017-11-20 09:07:00    User37          2 weeks
# 102 2017-11-13 14:44:00 2017-11-13 14:47:00    User37          1 weeks
# 103 2017-11-07 07:56:00 2017-11-07 07:59:00    User37            1 day
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 101     Excellent               Good           Improved  No effect
# 102     Excellent               Good          No effect  No effect
# 103     Excellent               Good                NaN        NaN
#
#     Drive_Passion_Motivation Physical_Energy       ...         \
# 101                 Improved        Improved       ...
# 102                 Improved       No effect       ...
# 103                      NaN             NaN       ...
#
#     Verbal_Fluency_Word_Recall Creativity_Insight  \
# 101                  No effect           Improved
# 102                  Less good          No effect
# ...

# %%
(df.loc[101:101,'User_Status']).fillna('XNootropic User', inplace=True)

# %%
df.loc[101:101]
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 101 2017-11-20 09:04:00 2017-11-20 09:07:00    User37          2 weeks
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 101     Excellent               Good           Improved  No effect
#
#     Drive_Passion_Motivation Physical_Energy       ...         \
# 101                 Improved        Improved       ...
#
#     Verbal_Fluency_Word_Recall Creativity_Insight  \
# 101                  No effect           Improved
#
#     InterpersonalCapability_Empathy Emotional_Stability  \
# 101                       No effect           No effect
#
#     Euhphoria_Joy_Happiness Estimated_Effect_Duration Upper_Effect_Duration  \
# 101               No effect                       4-8                   8.0
#
#     Lower_Effect_Duration  Current_User_Comparison      User_Status
# 101                   4.0                      NaN  XNootropic User
#
# [1 rows x 22 columns]

# %%
df[df.Memory.isnull()]
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 103 2017-11-07 07:56:00 2017-11-07 07:59:00    User37            1 day
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen Memory  \
# 103     Excellent               Good                NaN    NaN
#
#     Drive_Passion_Motivation Physical_Energy     ...       \
# 103                      NaN             NaN     ...
#
#     Verbal_Fluency_Word_Recall Creativity_Insight  \
# 103                        NaN                NaN
#
#     InterpersonalCapability_Empathy Emotional_Stability  \
# 103                             NaN                 NaN
#
#     Euhphoria_Joy_Happiness Estimated_Effect_Duration Upper_Effect_Duration  \
# 103                     NaN                       NaN                   NaN
#
#     Lower_Effect_Duration  Current_User_Comparison  User_Status
# 103                   NaN                      NaN          NaN
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Capacity for Productivity
#
# User21 did not answer for Day 1 but did answer for week 1, week 2, and week 3. Of the other three answers, the user answered that their capacity for productivity improved. This user can be imputed? But then again this is their first time trying Trial 051 and are a user.

# %%
df[df.Capacity_Productivity.isnull()]
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 59  2017-10-30 17:40:00 2017-10-30 17:42:00    User21            1 day
# 103 2017-11-07 07:56:00 2017-11-07 07:59:00    User37            1 day
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 59      Excellent               Good           Improved  No effect
# 103     Excellent               Good                NaN        NaN
#
#     Drive_Passion_Motivation Physical_Energy       ...         \
# 59                 No effect        Improved       ...
# 103                      NaN             NaN       ...
#
#     Verbal_Fluency_Word_Recall Creativity_Insight  \
# 59                   No effect          No effect
# 103                        NaN                NaN
#
#     InterpersonalCapability_Empathy Emotional_Stability  \
# 59                        No effect            Improved
# 103                             NaN                 NaN
#
# ...

# %%
df[df.Last_Name=='User21'][['Capacity_Productivity', 'Version_Duration']]
# Out:
#    Capacity_Productivity Version_Duration
# 56              Improved          3 weeks
# 57              Improved          2 weeks
# 58              Improved          1 weeks
# 59                   NaN            1 day

# %% [markdown]
# ## Verbal_Fluency_Word_Recall

# %%
df[df.Verbal_Fluency_Word_Recall.isnull()]
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 9   2017-11-06 06:33:00 2017-11-06 06:36:00     User3          1 weeks
# 40  2017-11-09 04:26:00 2017-11-09 04:28:00    User14          2 weeks
# 98  2017-11-19 08:11:00 2017-11-19 08:15:00    User35          1 weeks
# 103 2017-11-07 07:56:00 2017-11-07 07:59:00    User37            1 day
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 9       Excellent          Excellent           Improved   Improved
# 40      Excellent          Excellent           Improved   Improved
# 98      Excellent          Excellent           Improved  No effect
# 103     Excellent               Good                NaN        NaN
#
#     Drive_Passion_Motivation Physical_Energy       ...         \
# 9                   Improved       No effect       ...
# 40                  Improved       No effect       ...
# 98                  Improved        Improved       ...
# ...

# %%
df[df.Last_Name=='User3'][['Verbal_Fluency_Word_Recall', 'Version_Duration']]
#responded on day 1 and week 2. But did not respond on Week 1. Can I impute? They had improved on the other two responses
# Out:
#    Verbal_Fluency_Word_Recall Version_Duration
# 8                    Improved          2 weeks
# 9                         NaN          1 weeks
# 10                   Improved            1 day

# %%
df[df.Last_Name=='User14'][['Verbal_Fluency_Word_Recall', 'Version_Duration']]
#can impute
# Out:
#    Verbal_Fluency_Word_Recall Version_Duration
# 39                   Improved          3 weeks
# 40                        NaN          2 weeks
# 41                   Improved          1 weeks

# %%
df[df.Last_Name=='User35'][['Verbal_Fluency_Word_Recall', 'Version_Duration']]
#cannot impute
# Out:
#    Verbal_Fluency_Word_Recall Version_Duration
# 98                        NaN          1 weeks

# %% [markdown]
# ### Creativity_Insight

# %%
df[df.Creativity_Insight.isnull()]
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 40  2017-11-09 04:26:00 2017-11-09 04:28:00    User14          2 weeks
# 66  2017-11-18 09:12:00 2017-11-18 09:15:00    User25          1 weeks
# 103 2017-11-07 07:56:00 2017-11-07 07:59:00    User37            1 day
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 40      Excellent          Excellent           Improved   Improved
# 66             OK           Not good          Less good  No effect
# 103     Excellent               Good                NaN        NaN
#
#     Drive_Passion_Motivation Physical_Energy       ...         \
# 40                  Improved       No effect       ...
# 66                 Less good       No effect       ...
# 103                      NaN             NaN       ...
#
#     Verbal_Fluency_Word_Recall Creativity_Insight  \
# 40                         NaN                NaN
# 66                   No effect                NaN
# ...

# %%
df[df.Last_Name=='User14'][['Creativity_Insight', 'Version_Duration']]
#can impute for user14 since they answered for week 1, 2, and 3
# Out:
#    Creativity_Insight Version_Duration
# 39           Improved          3 weeks
# 40                NaN          2 weeks
# 41           Improved          1 weeks

# %%
df[df.Last_Name=='User25'][['Creativity_Insight', 'Version_Duration']]
# Out:
#    Creativity_Insight Version_Duration
# 66                NaN          1 weeks
# 67          No effect            1 day

# %% [markdown]
# ## Estimated Duration Effect

# %%
df[df.Estimated_Effect_Duration.isnull()]
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 1   2017-11-09 13:13:00 2017-11-09 13:16:00     User1          2 weeks
# 4   2017-11-16 19:45:00 2017-11-16 19:48:00     User2          3 weeks
# 5   2017-11-08 18:34:00 2017-11-08 18:37:00     User2          2 weeks
# 6   2017-11-01 06:10:00 2017-11-01 06:13:00     User2          1 weeks
# 7   2017-10-27 21:10:00 2017-10-27 21:13:00     User2            1 day
# 8   2017-11-11 06:38:00 2017-11-11 06:41:00     User3          2 weeks
# 16  2017-11-17 08:31:00 2017-11-17 08:33:00     User6          3 weeks
# 18  2017-10-27 09:36:00 2017-10-27 09:41:00     User6            1 day
# 19  2017-11-22 06:51:00 2017-11-22 06:53:00     User7          3 weeks
# 20  2017-11-13 15:05:00 2017-11-13 15:06:00     User7          2 weeks
# 21  2017-11-04 15:07:00 2017-11-04 15:10:00     User7          1 weeks
# 22  2017-10-30 04:19:00 2017-10-30 04:24:00     User7            1 day
# ...

# %%
df[df.Last_Name=='User1'][['Estimated_Effect_Duration', 'Version_Duration']]
#can impute
# Out:
#   Estimated_Effect_Duration Version_Duration
# 0                        <2          3 weeks
# 1                       NaN          2 weeks
# 2                        <2          1 weeks
# 3                        <2            1 day

# %%
df[df.Last_Name=='User2'][['Estimated_Effect_Duration', 'Version_Duration']]
# did not respond to any
# Out:
#   Estimated_Effect_Duration Version_Duration
# 4                       NaN          3 weeks
# 5                       NaN          2 weeks
# 6                       NaN          1 weeks
# 7                       NaN            1 day

# %%
df[df.Last_Name=='User3'][['Estimated_Effect_Duration', 'Version_Duration']]
# Out:
#    Estimated_Effect_Duration Version_Duration
# 8                        NaN          2 weeks
# 9                         <2          1 weeks
# 10                       4-8            1 day

# %%
df[df.Last_Name=='User6'][['Estimated_Effect_Duration', 'Version_Duration']]
# Out:
#    Estimated_Effect_Duration Version_Duration
# 16                       NaN          3 weeks
# 17                       4-8          1 weeks
# 18                       NaN            1 day

# %%
df[df.Last_Name=='User7'][['Estimated_Effect_Duration', 'Version_Duration']]
# Out:
#    Estimated_Effect_Duration Version_Duration
# 19                       NaN          3 weeks
# 20                       NaN          2 weeks
# 21                       NaN          1 weeks
# 22                       NaN            1 day

# %%
df[df.Last_Name=='User9'][['Estimated_Effect_Duration', 'Version_Duration']]
#can impute
# Out:
#    Estimated_Effect_Duration Version_Duration
# 24                       4-8          3 weeks
# 25                        8+          2 weeks
# 26                       4-8          1 weeks
# 27                       NaN            1 day

# %%
df[df.Last_Name=='User12'][['Estimated_Effect_Duration', 'Version_Duration']]
# Out:
#    Estimated_Effect_Duration Version_Duration
# 31                       NaN          3 weeks
# 32                       NaN          2 weeks
# 33                       NaN          1 weeks
# 34                        <2            1 day

# %%
df[df.Last_Name=='User21'][['Estimated_Effect_Duration', 'Version_Duration']]
# can impute
# Out:
#    Estimated_Effect_Duration Version_Duration
# 56                       4-8          3 weeks
# 57                       4-8          2 weeks
# 58                       4-8          1 weeks
# 59                       NaN            1 day

# %%
df[df.Last_Name=='User27'][['Estimated_Effect_Duration', 'Version_Duration']]
# can impute
# Out:
#    Estimated_Effect_Duration Version_Duration
# 72                       4-8          2 weeks
# 73                       NaN          1 weeks
# 74                       4-8            1 day

# %%
df[df.Last_Name=='User28'][['Estimated_Effect_Duration', 'Version_Duration']]
# Out:
#    Estimated_Effect_Duration Version_Duration
# 75                       NaN          1 weeks
# 76                       NaN            1 day

# %%
df[df.Last_Name=='User37'][['Estimated_Effect_Duration', 'Version_Duration']]
#impute
# Out:
#     Estimated_Effect_Duration Version_Duration
# 101                       4-8          2 weeks
# 102                       4-8          1 weeks
# 103                       NaN            1 day

# %%
df[df.Last_Name=='User38'][['Estimated_Effect_Duration', 'Version_Duration']]
# Out:
#     Estimated_Effect_Duration Version_Duration
# 104                        8+          1 weeks
# 105                       NaN            1 day

# %%
df[df.Last_Name=='User39'][['Estimated_Effect_Duration', 'Version_Duration']]
#impute
# Out:
#     Estimated_Effect_Duration Version_Duration
# 106                       NaN          3 weeks
# 107                       NaN          2 weeks
# 108                       4-8          1 weeks
# 109                       4-8            1 day

# %%
df[df.Last_Name=='User41'][['Estimated_Effect_Duration', 'Version_Duration']]
#impute
# Out:
#     Estimated_Effect_Duration Version_Duration
# 112                       NaN          2 weeks
# 113                        <2          1 weeks
# 114                        <2            1 day

# %% [markdown]
# ## User Status/Current User Comparison

# %%
df[df.Current_User_Comparison.isnull()]
# Out:
#              Start_Date            End_Date Last_Name Version_Duration  \
# 4   2017-11-16 19:45:00 2017-11-16 19:48:00     User2          3 weeks
# 6   2017-11-01 06:10:00 2017-11-01 06:13:00     User2          1 weeks
# 13  2017-11-19 18:33:00 2017-11-19 18:35:00     User5          2 weeks
# 82  2017-11-02 19:45:00 2017-11-02 19:49:00    User30            1 day
# 101 2017-11-20 09:04:00 2017-11-20 09:07:00    User37          2 weeks
# 103 2017-11-07 07:56:00 2017-11-07 07:59:00    User37            1 day
# 112 2017-11-13 08:15:00 2017-11-13 08:17:00    User41          2 weeks
#
#     Sleep_Quality Overall_Experience Focus_Atten_Concen     Memory  \
# 4              OK          No effect          No effect  No effect
# 6              OK          No effect          No effect  No effect
# 13      Excellent          Excellent           Improved   Improved
# 82      Excellent          Excellent           Improved   Improved
# ...

# %%
df[df.Last_Name=='User2'][['Current_User_Comparison', 'Version_Duration','User_Status']]
#can fill in value for this person
# Out:
#       Current_User_Comparison Version_Duration User_Status
# 4                         NaN          3 weeks         NaN
# 5  I am not a XNootropic user          2 weeks    Non-user
# 6                         NaN          1 weeks         NaN
# 7  I am not a XNootropic user            1 day    Non-user

# %%
df.loc[4:7, 'Current_User_Comparison'].fillna('I am not a XNtootropic user', inplace=True)

# %%
df.loc[4:7, 'User_Status'].fillna('Non-user', inplace=True)

# %%
df[df.Last_Name=='User30'][['Current_User_Comparison', 'Version_Duration','User_Status']]
# Out:
#        Current_User_Comparison Version_Duration User_Status
# 80  I am not a XNootropic user          2 weeks    Non-user
# 81  I am not a XNootropic user          1 weeks    Non-user
# 82                         NaN            1 day         NaN

# %%
df.loc[82:82, 'Current_User_Comparison'].fillna('I am not a XNootropic user', inplace=True)

# %%
df.loc[82:82, 'User_Status'].fillna('Non-user', inplace=True)

# %% [markdown]
# # QUESTION
# #do you think they think they are a user after taking it the drug?

# %%
df[df.Last_Name=='User37'][['Current_User_Comparison', 'Version_Duration','User_Status']]
# Out:
#                Current_User_Comparison Version_Duration      User_Status
# 101                                NaN          2 weeks  XNootropic User
# 102  This is less good than XNootropic          1 weeks  XNootropic User
# 103                                NaN            1 day              NaN

# %% [markdown]
# # QUESTION
# confusing, they said they are a user then they are non-user...did they answer this incorrectly?

# %%
df[df.Last_Name=='User41'][['Current_User_Comparison', 'Version_Duration','User_Status']]
# Out:
#             Current_User_Comparison Version_Duration      User_Status
# 112                             NaN          2 weeks              NaN
# 113      I am not a XNootropic user          1 weeks         Non-user
# 114  This is better than XNootropic            1 day  XNootropic User

# %%
df.to_csv('Trial_051_Cleaned', index=False)
